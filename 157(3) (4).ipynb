# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data_clean.csv")
print(data)
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
print(type(data))
print(data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (158, 10)

# %%
data.shape
# Out:
# (158, 10)

# %%
data.dtypes
# Out:
# Unnamed: 0      int64
# Ozone         float64
# Solar.R       float64
# Wind          float64
# Temp C         object
# Month          object
# Day             int64
# Year            int64
# Temp            int64
# Weather        object
# dtype: object

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  158 non-null    int64
#  1   Ozone       120 non-null    float64
#  2   Solar.R     151 non-null    float64
#  3   Wind        158 non-null    float64
#  4   Temp C      158 non-null    object
#  5   Month       158 non-null    object
#  6   Day         158 non-null    int64
#  7   Year        158 non-null    int64
#  8   Temp        158 non-null    int64
#  9   Weather     155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
data.rename({'Solar.R': 'Solar'}, axis=1, inplace=True)
data.rename({'Temp': 'Temperature'}, axis=1, inplace=True)
data
# Out:
#      Unnamed: 0  Ozone  Solar  Wind Temp C Month  Day  Year  Temperature  \
# 0             1   41.0  190.0   7.4     67     5    1  2010           67
# 1             2   36.0  118.0   8.0     72     5    2  2010           72
# 2             3   12.0  149.0  12.6     74     5    3  2010           74
# 3             4   18.0  313.0  11.5     62     5    4  2010           62
# 4             5    NaN    NaN  14.3     56     5    5  2010           56
# ..          ...    ...    ...   ...    ...   ...  ...   ...          ...
# 153         154   41.0  190.0   7.4     67     5    1  2010           67
# 154         155   30.0  193.0   6.9     70     9   26  2010           70
# 155         156    NaN  145.0  13.2     77     9   27  2010           77
# 156         157   14.0  191.0  14.3     75     9   28  2010           75
# 157         158   18.0  131.0   8.0     76     9   29  2010           76
#
#     Weather
# 0         S
# 1         C
# 2        PS
# 3         S
# 4         S
# ..      ...
# 153       C
# 154      PS
# 155       S
# 156       S
# 157       C
#
# [158 rows x 10 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   158 non-null    int64
#  1   Ozone        120 non-null    float64
#  2   Solar        151 non-null    float64
#  3   Wind         158 non-null    float64
#  4   Temp C       158 non-null    object
#  5   Month        158 non-null    object
#  6   Day          158 non-null    int64
#  7   Year         158 non-null    int64
#  8   Temperature  158 non-null    int64
#  9   Weather      155 non-null    object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 12.5+ KB

# %%
# Display data  missing values count in each column using isnull().sum()
data.isnull().sum()
# Out:
# Unnamed: 0      0
# Ozone          38
# Solar           7
# Wind            0
# Temp C          0
# Month           0
# Day             0
# Year            0
# Temperature     0
# Weather         3
# dtype: int64

# %%
#Visualize data missing using graph
cols = data.columns
colours=['black','Red']
sns.heatmap(data[cols].isnull(),cmap=sns.color_palette(colours),cbar = True)
# Out:
# <Axes: >

# %%
median_ozone = data["Ozone"].median()
mean_ozone = data["Ozone"].mean()
print("Median of Ozone: ", median_ozone)
print("Mean of Ozone: ", mean_ozone)
# Out:
# Median of Ozone:  30.5
# Mean of Ozone:  41.583333333333336

# %%
data['Ozone']=data['Ozone'].fillna(median_ozone)
data.isnull().sum()
# Out:
# Unnamed: 0     0
# Ozone          0
# Solar          7
# Wind           0
# Temp C         0
# Month          0
# Day            0
# Year           0
# Temperature    0
# Weather        3
# dtype: int64

# %%
median_ozone = data["Solar"].median()
mean_ozone = data["Solar"].mean()
print("Median of Solar: ", median_ozone)
print("Mean of Solar: ", mean_ozone)
# Out:
# Median of Solar:  197.0
# Mean of Solar:  185.40397350993376

# %%
data['Solar']=data['Solar'].fillna(median_ozone)
data.isnull().sum()
# Out:
# Unnamed: 0     0
# Ozone          0
# Solar          0
# Wind           0
# Temp C         0
# Month          0
# Day            0
# Year           0
# Temperature    0
# Weather        3
# dtype: int64

# %%
print(data["Weather"].value_counts())
mode_weather = data["Weather"].mode()[0]
print(mode_weather)
# Out:
# Weather
# S     59
# C     49
# PS    47
# Name: count, dtype: int64
# S

# %%
data["weather"]=data["Weather"].fillna(mode_weather)
data.isnull().sum()
# Out:
# Unnamed: 0     0
# Ozone          0
# Solar          0
# Wind           0
# Temp C         0
# Month          0
# Day            0
# Year           0
# Temperature    0
# Weather        3
# weather        0
# dtype: int64

# %%
print(data["Month"].value_counts())
mode_Month = data["Month"].mode()[0]
print(mode_Month)
# Out:
# Month
# 9      34
# 5      31
# 7      31
# 8      31
# 6      30
# May     1
# Name: count, dtype: int64
# 9

# %%
data["Month"]=data["Month"].fillna(mode_Month)
data.isnull().sum()
# Out:
# Unnamed: 0     0
# Ozone          0
# Solar          0
# Wind           0
# Temp C         0
# Month          0
# Day            0
# Year           0
# Temperature    0
# Weather        3
# weather        0
# dtype: int64

# %%
data.tail()
# Out:
#      Unnamed: 0  Ozone  Solar  Wind Temp C Month  Day  Year  Temperature  \
# 153         154   41.0  190.0   7.4     67     5    1  2010           67
# 154         155   30.0  193.0   6.9     70     9   26  2010           70
# 155         156   30.5  145.0  13.2     77     9   27  2010           77
# 156         157   14.0  191.0  14.3     75     9   28  2010           75
# 157         158   18.0  131.0   8.0     76     9   29  2010           76
#
#     Weather weather
# 153       C       C
# 154      PS      PS
# 155       S       S
# 156       S       S
# 157       C       C

# %%
data.reset_index(drop=True)
# Out:
#      Unnamed: 0  Ozone  Solar  Wind Temp C Month  Day  Year  Temperature  \
# 0             1   41.0  190.0   7.4     67     5    1  2010           67
# 1             2   36.0  118.0   8.0     72     5    2  2010           72
# 2             3   12.0  149.0  12.6     74     5    3  2010           74
# 3             4   18.0  313.0  11.5     62     5    4  2010           62
# 4             5   30.5  197.0  14.3     56     5    5  2010           56
# ..          ...    ...    ...   ...    ...   ...  ...   ...          ...
# 153         154   41.0  190.0   7.4     67     5    1  2010           67
# 154         155   30.0  193.0   6.9     70     9   26  2010           70
# 155         156   30.5  145.0  13.2     77     9   27  2010           77
# 156         157   14.0  191.0  14.3     75     9   28  2010           75
# 157         158   18.0  131.0   8.0     76     9   29  2010           76
#
#     Weather weather
# 0         S       S
# 1         C       C
# 2        PS      PS
# 3         S       S
# 4         S       S
# ..      ...     ...
# 153       C       C
# 154      PS      PS
# 155       S       S
# 156       S       S
# 157       C       C
#
# [158 rows x 11 columns]

# %%
fig,axes =plt.subplots(2,1,figsize=(8,6),gridspec_kw={'height_ratios':[1,3]})
sns.boxplot(data=data["Ozone"],ax=axes[0],color='skyblue',width=0.5,orient='h')
axes[0].set_title("Boxplot")
axes[0].set_xlabel("Ozone Levels")
sns.histplot(data["Ozone"],kde=True,ax=axes[1],color='purple',bins=30)
axes[1].set_title("Histogram with KDE")
axes[0].set_xlabel("Ozone Levels")
axes[0].set_ylabel("Frequency")
plt.tight_layout()
plt.show()

# %% [markdown]
# #observations
# -the ozone columns has extreme values beyond 81 as seen from box plot
# -the same is confirmed from the below right-skewed histogram

# %%
sns.violinplot(data=data["Ozone"],color='lightgreen')
plt.title("Violin plot")
# Out:
# Text(0.5, 1.0, 'Violin plot')

# %%
plt.figure(figsize=(6,2))
boxplot_data=plt.boxplot(data["Ozone"], vert=False)
[item.get_xdata() for item in boxplot_data['fliers']]
# Out:
# [array([115., 135.,  97.,  97.,  85., 108.,  82., 122.,  89., 110., 168.,
#         118.,  84.,  85.,  96.,  91.])]

# %% [markdown]
# # method 2 for outlier detection

# %%
data["Ozone"].describe()
# Out:
# count    158.000000
# mean      38.917722
# std       28.794730
# min        1.000000
# 25%       21.000000
# 50%       30.500000
# 75%       45.000000
# max      168.000000
# Name: Ozone, dtype: float64

# %%
mu = data["Ozone"].describe()[1]
sigma= data["Ozone"].describe()[2]
for x in data["Ozone"]:
    if ((x < (mu - 3*sigma)) or (x > (mu + 3*sigma))):
        print(x)
# Out:
# 135.0
# 168.0
# C:\Users\daggu\AppData\Local\Temp\ipykernel_13060\2881425674.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   mu = data["Ozone"].describe()[1]
# C:\Users\daggu\AppData\Local\Temp\ipykernel_13060\2881425674.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   sigma= data["Ozone"].describe()[2]

# %% [markdown]
# # observation
# - it is observed that only two outliers are idenfied using std method
# - in box plot menthod more no of outliers are identified
# - this is because the assumption of normality is not satified in the column

# %%
# quantile-quantile plot for detection of outliers

# %%
import scipy.stats as stats
plt.figure (figsize =(8,6))
stats.probplot (data ["Ozone"], dist= "norm",plot =plt)
plt.title("Q-Q plot for outliers Detection", fontsize=15)
plt.xlabel("Theretical Quantiles",fontsize=12)
# Out:
# Text(0.5, 0, 'Theretical Quantiles')

# %% [markdown]
# # Observations from Q-Q plot
# - the dataa does not follow normal distribution as the data points are deviatiing significantly away from the from the red line
# - the data show a right-skewed distribution and possible outilers

# %% [markdown]
# # Other visualisations that could help in the deection of outliers

# %%
sns.swarmplot(data=data, x= "Weather", y ="Ozone",color="orange",palette="Set2",size=6)
# Out:
# C:\Users\daggu\AppData\Local\Temp\ipykernel_13060\281142669.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(data=data, x= "Weather", y ="Ozone",color="orange",palette="Set2",size=6)
# <Axes: xlabel='Weather', ylabel='Ozone'>
# C:\Users\daggu\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 5.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.stripplot(data=data, x= "Weather", y ="Ozone",color="orange",palette="Set1",size=6,jitter=True)
# Out:
# C:\Users\daggu\AppData\Local\Temp\ipykernel_13060\172041042.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=data, x= "Weather", y ="Ozone",color="orange",palette="Set1",size=6,jitter=True)
# <Axes: xlabel='Weather', ylabel='Ozone'>

# %%
sns.kdeplot(data=data["Ozone"],fill=True,color="blue")
sns.rugplot(data=data["Ozone"],color="black")
# Out:
# <Axes: xlabel='Ozone', ylabel='Density'>

# %%
plt.scatter(data["Wind"],data["Temperature"])

# %%
#compute pearson correlation coefficient
#between wind speeed and temperature
data["Wind"].corr(data["Temperature"])
# Out:
# -0.441246717631239

# %%
data_numeric =data.iloc[:,[0,1,2,6]]
data_numeric
# Out:
#      Unnamed: 0  Ozone  Solar  Day
# 0             1   41.0  190.0    1
# 1             2   36.0  118.0    2
# 2             3   12.0  149.0    3
# 3             4   18.0  313.0    4
# 4             5   30.5  197.0    5
# ..          ...    ...    ...  ...
# 153         154   41.0  190.0    1
# 154         155   30.0  193.0   26
# 155         156   30.5  145.0   27
# 156         157   14.0  191.0   28
# 157         158   18.0  131.0   29
#
# [158 rows x 4 columns]

# %%
data_numeric.corr()
# Out:
#             Unnamed: 0     Ozone     Solar       Day
# Unnamed: 0    1.000000  0.148419 -0.110187  0.216219
# Ozone         0.148419  1.000000  0.296048 -0.039298
# Solar        -0.110187  0.296048  1.000000 -0.154095
# Day           0.216219 -0.039298 -0.154095  1.000000

# %% [markdown]
# # Observation
# - the highest correlation strength is observed between Ozone and temperature(0.597087)
# - the next highest correlation strength is observed between Ozone and wind(-0.523738)
# - the next highest correlation strength is observed between wind and temp(-0.)
# - the next highest correlation strength is observed between Solar and wind(-0.)

# %%
# plot a pair plot between all numeric columns using seaborn
sns.pairplot(data_numeric)

# %%
#creating dummy variables for Weather column
data1=pd.get_dummies(data,columns=['Month','Weather'])
data1
# Out:
#      Unnamed: 0  Ozone  Solar  Wind Temp C  Day  Year  Temperature weather  \
# 0             1   41.0  190.0   7.4     67    1  2010           67       S
# 1             2   36.0  118.0   8.0     72    2  2010           72       C
# 2             3   12.0  149.0  12.6     74    3  2010           74      PS
# 3             4   18.0  313.0  11.5     62    4  2010           62       S
# 4             5   30.5  197.0  14.3     56    5  2010           56       S
# ..          ...    ...    ...   ...    ...  ...   ...          ...     ...
# 153         154   41.0  190.0   7.4     67    1  2010           67       C
# 154         155   30.0  193.0   6.9     70   26  2010           70      PS
# 155         156   30.5  145.0  13.2     77   27  2010           77       S
# 156         157   14.0  191.0  14.3     75   28  2010           75       S
# 157         158   18.0  131.0   8.0     76   29  2010           76       C
#
#      Month_5  Month_6  Month_7  Month_8  Month_9  Month_May  Weather_C  \
# 0       True    False    False    False    False      False      False
# 1       True    False    False    False    False      False       True
# 2       True    False    False    False    False      False      False
# 3       True    False    False    False    False      False      False
# 4       True    False    False    False    False      False      False
# ..       ...      ...      ...      ...      ...        ...        ...
# 153     True    False    False    False    False      False       True
# 154    False    False    False    False     True      False      False
# 155    False    False    False    False     True      False      False
# 156    False    False    False    False     True      False      False
# 157    False    False    False    False     True      False       True
#
#      Weather_PS  Weather_S
# 0         False       True
# 1         False      False
# 2          True      False
# 3         False       True
# 4         False       True
# ..          ...        ...
# 153       False      False
# 154        True      False
# 155       False       True
# 156       False       True
# 157       False      False
#
# [158 rows x 18 columns]

# %%
data_numeric.values
# Out:
# array([[  1. ,  41. , 190. ,   1. ],
#        [  2. ,  36. , 118. ,   2. ],
#        [  3. ,  12. , 149. ,   3. ],
#        [  4. ,  18. , 313. ,   4. ],
#        [  5. ,  30.5, 197. ,   5. ],
#        [  6. ,  28. , 197. ,   6. ],
#        [  7. ,  23. , 299. ,   7. ],
#        [  8. ,  19. ,  99. ,   8. ],
#        [  9. ,   8. ,  19. ,   9. ],
#        [ 10. ,  30.5, 194. ,  10. ],
#        [ 11. ,   7. , 197. ,  11. ],
#        [ 12. ,  16. , 256. ,  12. ],
#        [ 13. ,  11. , 290. ,  13. ],
#        [ 14. ,  14. , 274. ,  14. ],
#        [ 15. ,  18. ,  65. ,  15. ],
#        [ 16. ,  14. , 334. ,  16. ],
#        [ 17. ,  34. , 307. ,  17. ],
#        [ 18. ,   6. ,  78. ,  18. ],
#        [ 19. ,  30. , 322. ,  19. ],
#        [ 20. ,  11. ,  44. ,  20. ],
#        [ 21. ,   1. ,   8. ,  21. ],
#        [ 22. ,  11. , 320. ,  22. ],
#        [ 23. ,   4. ,  25. ,  23. ],
#        [ 24. ,  32. ,  92. ,  24. ],
#        [ 25. ,  30.5,  66. ,  25. ],
#        [ 26. ,  30.5, 266. ,  26. ],
#        [ 27. ,  30.5, 197. ,  27. ],
#        [ 28. ,  23. ,  13. ,  28. ],
#        [ 29. ,  45. , 252. ,  29. ],
#        [ 30. , 115. , 223. ,  30. ],
#        [ 31. ,  37. , 279. ,  31. ],
#        [ 32. ,  30.5, 286. ,   1. ],
#        [ 33. ,  30.5, 287. ,   2. ],
#        [ 34. ,  30.5, 242. ,   3. ],
#        [ 35. ,  30.5, 186. ,   4. ],
#        [ 36. ,  30.5, 220. ,   5. ],
#        [ 37. ,  30.5, 264. ,   6. ],
#        [ 38. ,  29. , 127. ,   7. ],
#        [ 39. ,  30.5, 273. ,   8. ],
#        [ 40. ,  71. , 291. ,   9. ],
#        [ 41. ,  39. , 323. ,  10. ],
#        [ 42. ,  30.5, 259. ,  11. ],
#        [ 43. ,  30.5, 250. ,  12. ],
#        [ 44. ,  23. , 148. ,  13. ],
#        [ 45. ,  30.5, 332. ,  14. ],
#        [ 46. ,  30.5, 322. ,  15. ],
#        [ 47. ,  21. , 191. ,  16. ],
#        [ 48. ,  37. , 284. ,  17. ],
#        [ 49. ,  20. ,  37. ,  18. ],
#        [ 50. ,  12. , 120. ,  19. ],
#        [ 51. ,  13. , 137. ,  20. ],
#        [ 52. ,  30.5, 150. ,  21. ],
#        [ 53. ,  30.5,  59. ,  22. ],
#        [ 54. ,  30.5,  91. ,  23. ],
#        [ 55. ,  30.5, 250. ,  24. ],
#        [ 56. ,  30.5, 135. ,  25. ],
#        [ 57. ,  30.5, 127. ,  26. ],
#        [ 58. ,  30.5,  47. ,  27. ],
#        [ 59. ,  30.5,  98. ,  28. ],
#        [ 60. ,  30.5,  31. ,  29. ],
#        [ 61. ,  30.5, 138. ,  30. ],
#        [ 62. , 135. , 269. ,   1. ],
#        [ 63. ,  49. , 248. ,   2. ],
#        [ 64. ,  32. , 236. ,   3. ],
#        [ 65. ,  30.5, 101. ,   4. ],
#        [ 66. ,  64. , 175. ,   5. ],
#        [ 67. ,  40. , 314. ,   6. ],
#        [ 68. ,  77. , 276. ,   7. ],
#        [ 69. ,  97. , 267. ,   8. ],
#        [ 70. ,  97. , 272. ,   9. ],
#        [ 71. ,  85. , 175. ,  10. ],
#        [ 72. ,  30.5, 139. ,  11. ],
#        [ 73. ,  10. , 264. ,  12. ],
#        [ 74. ,  27. , 175. ,  13. ],
#        [ 75. ,  30.5, 291. ,  14. ],
#        [ 76. ,   7. ,  48. ,  15. ],
#        [ 77. ,  48. , 260. ,  16. ],
#        [ 78. ,  35. , 274. ,  17. ],
#        [ 79. ,  61. , 285. ,  18. ],
#        [ 80. ,  79. , 187. ,  19. ],
#        [ 81. ,  63. , 220. ,  20. ],
#        [ 82. ,  16. ,   7. ,  21. ],
#        [ 83. ,  30.5, 258. ,  22. ],
#        [ 84. ,  30.5, 295. ,  23. ],
#        [ 85. ,  80. , 294. ,  24. ],
#        [ 86. , 108. , 223. ,  25. ],
#        [ 87. ,  20. ,  81. ,  26. ],
#        [ 88. ,  52. ,  82. ,  27. ],
#        [ 89. ,  82. , 213. ,  28. ],
#        [ 90. ,  50. , 275. ,  29. ],
#        [ 91. ,  64. , 253. ,  30. ],
#        [ 92. ,  59. , 254. ,  31. ],
#        [ 93. ,  39. ,  83. ,   1. ],
#        [ 94. ,   9. ,  24. ,   2. ],
#        [ 95. ,  16. ,  77. ,   3. ],
#        [ 96. ,  78. , 197. ,   4. ],
#        [ 97. ,  35. , 197. ,   5. ],
#        [ 98. ,  66. , 197. ,   6. ],
#        [ 99. , 122. , 255. ,   7. ],
#        [100. ,  89. , 229. ,   8. ],
#        [101. , 110. , 207. ,   9. ],
#        [102. ,  30.5, 222. ,  10. ],
#        [103. ,  30.5, 137. ,  11. ],
#        [104. ,  44. , 192. ,  12. ],
#        [105. ,  28. , 273. ,  13. ],
#        [106. ,  65. , 157. ,  14. ],
#        [107. ,  30.5,  64. ,  15. ],
#        [108. ,  22. ,  71. ,  16. ],
#        [109. ,  59. ,  51. ,  17. ],
#        [110. ,  23. , 115. ,  18. ],
#        [111. ,  31. , 244. ,  19. ],
#        [112. ,  44. , 190. ,  20. ],
#        [113. ,  21. , 259. ,  21. ],
#        [114. ,   9. ,  36. ,  22. ],
#        [115. ,  30.5, 255. ,  23. ],
#        [116. ,  45. , 212. ,  24. ],
#        [117. , 168. , 238. ,  25. ],
#        [118. ,  73. , 215. ,  26. ],
#        [119. ,  30.5, 153. ,  27. ],
#        [120. ,  76. , 203. ,  28. ],
#        [121. , 118. , 225. ,  29. ],
#        [122. ,  84. , 237. ,  30. ],
#        [123. ,  85. , 188. ,  31. ],
#        [124. ,  96. , 167. ,   1. ],
#        [125. ,  78. , 197. ,   2. ],
#        [126. ,  73. , 183. ,   3. ],
#        [127. ,  91. , 189. ,   4. ],
#        [128. ,  47. ,  95. ,   5. ],
#        [129. ,  32. ,  92. ,   6. ],
#        [130. ,  20. , 252. ,   7. ],
#        [131. ,  23. , 220. ,   8. ],
#        [132. ,  21. , 230. ,   9. ],
#        [133. ,  24. , 259. ,  10. ],
#        [134. ,  44. , 236. ,  11. ],
#        [135. ,  21. , 259. ,  12. ],
#        [136. ,  28. , 238. ,  13. ],
#        [137. ,   9. ,  24. ,  14. ],
#        [138. ,  13. , 112. ,  15. ],
#        [139. ,  46. , 237. ,  16. ],
#        [140. ,  18. , 224. ,  17. ],
#        [141. ,  13. ,  27. ,  18. ],
#        [142. ,  24. , 238. ,  19. ],
#        [143. ,  16. , 201. ,  20. ],
#        [144. ,  13. , 238. ,  21. ],
#        [145. ,  23. ,  14. ,  22. ],
#        [146. ,  36. , 139. ,  23. ],
#        [147. ,   7. ,  49. ,  24. ],
#        [148. ,  14. ,  20. ,  25. ],
#        [149. ,  30. , 193. ,  26. ],
#        [150. ,  30.5, 145. ,  27. ],
#        [151. ,  14. , 191. ,  28. ],
#        [152. ,  18. , 131. ,  29. ],
#        [153. ,  20. , 223. ,  30. ],
#        [154. ,  41. , 190. ,   1. ],
#        [155. ,  30. , 193. ,  26. ],
#        [156. ,  30.5, 145. ,  27. ],
#        [157. ,  14. , 191. ,  28. ],
#        [158. ,  18. , 131. ,  29. ]])

# %%
#Normalization of the data
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler
array  = data_numeric.values
scaler = MinMaxScaler(feature_range=(0,1))
rescaledX = scaler.fit_transform(array)
#transformed data
set_printoptions(precision=2)
print(rescaledX[0:10,:])
# Out:
# [[0.   0.24 0.56 0.  ]
#  [0.01 0.21 0.34 0.03]
#  [0.01 0.07 0.43 0.07]
#  [0.02 0.1  0.94 0.1 ]
#  [0.03 0.18 0.58 0.13]
#  [0.03 0.16 0.58 0.17]
#  [0.04 0.13 0.89 0.2 ]
#  [0.04 0.11 0.28 0.23]
#  [0.05 0.04 0.04 0.27]
#  [0.06 0.18 0.57 0.3 ]]
